# %% [markdown]
# # Conic10K audit Colab
# Downloads Conic10K, runs the real-field audit, and creates the seeded stratified 100-item review sample.

# %%
# !git clone https://github.com/whyNLP/Conic10K.git /content/Conic10K

# %%
# From this repository root after checkout:
# !python scripts/download_conic10k.py --out-dir data/conic10k
# !python -m conic10k.audit --data-dir data/conic10k --out-dir artifacts/conic10k --sample-size 100 --seed 20260623
